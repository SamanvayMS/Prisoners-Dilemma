# %%
import axelrod as axl

# %%
axl.game.DefaultGame.RPST()
# Out:
# (3, 1, 0, 5)

# %%
first_tournament_participants_ordered_by_reported_rank = [s() for s in axl.axelrod_first_strategies]

# %%
tournament = axl.Tournament(
    players=first_tournament_participants_ordered_by_reported_rank,
    turns=200,
    repetitions=5
)
results = tournament.play()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:25<00:00,  4.64it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 271.59it/s]

# %%
for name in results.ranked_names:
    print(name)
plot = axl.Plot(results)
p = plot.boxplot()
p.show()
p = plot.winplot()
p.show()
p = plot.payoff()
p.show()
# Out:
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# First by Grofman
# First by Stein and Rapoport: 0.05: (D, D)
# First by Tideman and Chieruzzi: (D, D)
# First by Nydegger
# Tit For Tat
# First by Shubik
# Grudger
# First by Davis: 10
# First by Downing
# First by Graaskamp: 0.05
# First by Feld: 1.0, 0.5, 200
# First by Joss: 0.9
# First by Tullock
# Random: 0.5
# First by Anonymous

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6)) 
plt.plot((0, 15), (0, 15), color="grey", linestyle="--")  
for original_rank, strategy in enumerate(first_tournament_participants_ordered_by_reported_rank):
    rank = results.ranked_names.index(str(strategy))
    if rank == original_rank:
        symbol = "+"
        plt.plot((rank, rank), (rank, 0), color="grey")
    else:
        symbol = "o"
    plt.scatter([rank], [original_rank], marker=symbol, color="black", s=50)  
plt.xticks(
    range(len(first_tournament_participants_ordered_by_reported_rank)),
    results.ranked_names,
    rotation=90
)  
plt.ylabel("Reported rank")  
plt.xlabel("Reproduced rank");  
plt.show()

# %% [markdown]
# # Probababilistic end

# %%
tournament = axl.Tournament(
    players=first_tournament_participants_ordered_by_reported_rank,
    prob_end = 0.1)
results = tournament.play()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:00<00:00, 180.44it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 286.44it/s]

# %%
for name in results.ranked_names:
    print(name)
plot = axl.Plot(results)
p = plot.boxplot()
p.show()
p = plot.winplot()
p.show()
p = plot.payoff()
p.show()
# Out:
# First by Downing
# First by Feld: 1.0, 0.5, 200
# First by Tideman and Chieruzzi: (D, D)
# First by Joss: 0.9
# Grudger
# First by Graaskamp: 0.05
# First by Stein and Rapoport: 0.05: (D, D)
# Tit For Tat
# First by Nydegger
# First by Shubik
# First by Anonymous
# First by Grofman
# Random: 0.5
# First by Tullock
# First by Davis: 10
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
tournament = axl.Tournament(
    players=first_tournament_participants_ordered_by_reported_rank,
    prob_end = 0.01)
results = tournament.play()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:02<00:00, 48.84it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 261.29it/s]

# %%
for name in results.ranked_names:
    print(name)
plot = axl.Plot(results)
p = plot.boxplot()
p.show()
p = plot.winplot()
p.show()
p = plot.payoff()
p.show()
# Out:
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# /var/folders/yf/nhpg9fnj0577hsnsx3y4cd8h0000gn/T/ipykernel_97699/2296968963.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# First by Stein and Rapoport: 0.05: (D, D)
# Tit For Tat
# First by Shubik
# First by Tideman and Chieruzzi: (D, D)
# First by Graaskamp: 0.05
# Grudger
# First by Grofman
# First by Nydegger
# First by Davis: 10
# First by Feld: 1.0, 0.5, 200
# First by Downing
# First by Tullock
# First by Joss: 0.9
# First by Anonymous
# Random: 0.5
